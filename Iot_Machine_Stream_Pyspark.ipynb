# %% [markdown]
# Automating Data Pipelines with Pyspark SQL

# %%
dbutils.widgets.dropdown("samples", "calories_burnt", ["calories_burnt","average_heart_rate"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.widgets.text("FilePath", "/db_sample_files")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
table_name = dbutils.widgets.get("samples")
file_path = dbutils.widgets.get("FilePath")
print(table_name)
print(file_path)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">calories_burnt
# /db_sample_files
# </div>

# %%
# %sh
wget -O /dbfs/calories_burnt.json https://raw.githubusercontent.com/austinyoung123/dbtestingsamples/master/calories_burnt.json
wget -O /dbfs/average_heart_rate.json https://raw.githubusercontent.com/austinyoung123/dbtestingsamples/master/average_heart_rate.json
wget -O /dbfs/calories_burnt.txt https://raw.githubusercontent.com/austinyoung123/dbtestingsamples/master/calories_burnt.txt
wget -O /dbfs/average_heart_rate.txt https://raw.githubusercontent.com/austinyoung123/dbtestingsamples/master/average_heart_rate.txt
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--2021-01-09 23:49:22--  https://raw.githubusercontent.com/austinyoung123/dbtestingsamples/master/calories_burnt.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.64.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.64.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 840 [text/plain]
# Saving to: ‘/dbfs/calories_burnt.json’
#
#      0K                                                       100% 27.0M=0s
#
# 2021-01-09 23:49:22 (27.0 MB/s) - ‘/dbfs/calories_burnt.json’ saved [840/840]
#
# --2021-01-09 23:49:22--  https://raw.githubusercontent.com/austinyoung123/dbtestingsamples/master/average_heart_rate.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.64.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.64.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 794 [text/plain]
# Saving to: ‘/dbfs/average_heart_rate.json’
#
#      0K                                                       100% 26.7M=0s
#
# 2021-01-09 23:49:22 (26.7 MB/s) - ‘/dbfs/average_heart_rate.json’ saved [794/794]
#
# --2021-01-09 23:49:22--  https://raw.githubusercontent.com/austinyoung123/dbtestingsamples/master/calories_burnt.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.64.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.64.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 216 [text/plain]
# Saving to: ‘/dbfs/calories_burnt.txt’
#
#      0K                                                       100% 10.8M=0s
#
# 2021-01-09 23:49:22 (10.8 MB/s) - ‘/dbfs/calories_burnt.txt’ saved [216/216]
#
# --2021-01-09 23:49:22--  https://raw.githubusercontent.com/austinyoung123/dbtestingsamples/master/average_heart_rate.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.64.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.64.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 226 [text/plain]
# Saving to: ‘/dbfs/average_heart_rate.txt’
#
#      0K                                                       100% 8.82M=0s
#
# 2021-01-09 23:49:23 (8.82 MB/s) - ‘/dbfs/average_heart_rate.txt’ saved [226/226]
#
# </div>

# %%
# %sh
cd /dbfs
ls
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">FileStore
# average_heart_rate.json
# average_heart_rate.txt
# calories_burnt.json
# calories_burnt.txt
# databricks
# databricks-datasets
# databricks-results
# dbacademy
# local_disk0
# ml
# mnt
# tmp
# user
# </div>

# %%
dbutils.fs.mkdirs(f'{file_path}')
dbutils.fs.mkdirs(f'{file_path}/calories_burnt')
dbutils.fs.mkdirs(f'{file_path}/average_heart_rate')
dbutils.fs.cp('file:/dbfs/calories_burnt.json', f'{file_path}/calories_burnt')
dbutils.fs.cp('file:/dbfs/average_heart_rate.json', f'{file_path}/average_heart_rate')
dbutils.fs.cp('file:/dbfs/calories_burnt.txt', f'{file_path}')
dbutils.fs.cp('file:/dbfs/average_heart_rate.txt', f'{file_path}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: True</div>

# %%
dbutils.fs.ls(f'{file_path}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [FileInfo(path=&#39;dbfs:/db_sample_files/average_heart_rate/&#39;, name=&#39;average_heart_rate/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/db_sample_files/average_heart_rate.txt&#39;, name=&#39;average_heart_rate.txt&#39;, size=226),
#  FileInfo(path=&#39;dbfs:/db_sample_files/calories_burnt/&#39;, name=&#39;calories_burnt/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/db_sample_files/calories_burnt.txt&#39;, name=&#39;calories_burnt.txt&#39;, size=216)]</div>

# %%
schema_location = f"file:/dbfs/{table_name}.json"

###Take a single file with the proper schema and use as your "Hacky" schema

schema_file = spark.read.option("multiLine",True).format('json') \
  .load(schema_location).schema

schema_file
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: StructType(List(StructField(data,StructType(List(StructField(results,ArrayType(StructType(List(StructField(calories_burnt,DoubleType,true),StructField(device_id,LongType,true),StructField(miles_walked,DoubleType,true),StructField(num_steps,LongType,true),StructField(time_stamp,StringType,true),StructField(user_id,LongType,true))),true),true))),true)))</div>

# %%
df = spark.read.format('json').option('multiLine', True).load(f'{file_path}/{table_name}')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>data</th></tr></thead><tbody><tr><td>List(List(List(250.6999969482422, 5, 2.506999969482422, 5014, 2018-07-21 13:53:32.530695, 24), List(365.70001220703125, 5, 3.6570000648498535, 7314, 2018-07-24 02:37:36.530805, 4), List(126.80000305175781, 13, 1.2680000066757202, 2536, 2018-07-22 14:24:34.530772, 24), List(365.70001220703125, 5, 3.6570000648498535, 7314, 2018-07-24 02:37:36.530805, 4)))</td></tr></tbody></table></div>

# %% [markdown]
# Streaming Application

# %%
print(f'{file_path}/{table_name}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/db_sample_files/calories_burnt
# </div>

# %%
from pyspark.sql.functions import col, explode

stream_location = f'{file_path}/{table_name}'

#You can't infer the schema with a streaming source DataFrame!

df = spark.readStream.format('json').option('multiLine',True).schema(schema_file).load(stream_location).select(col("data.*")).withColumn("results", explode(col("results"))).select(col("results.*")) \
.writeStream \
.trigger(once=True) \
.format("delta") \
.option("checkpointLocation", f'{file_path}/Checkpoints/Ingest/{table_name}') \
.outputMode("append") \
.queryName("example_stream") \
.partitionBy("user_id") \
.start(f'{file_path}/Ingest/{table_name}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(spark.sql(f"""select  * from delta.`{file_path}/Ingest/{table_name}`"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>calories_burnt</th><th>device_id</th><th>miles_walked</th><th>num_steps</th><th>time_stamp</th><th>user_id</th></tr></thead><tbody><tr><td>365.70001220703125</td><td>5</td><td>3.6570000648498535</td><td>7314</td><td>2018-07-24 02:37:36.530805</td><td>4</td></tr><tr><td>365.70001220703125</td><td>5</td><td>3.6570000648498535</td><td>7314</td><td>2018-07-24 02:37:36.530805</td><td>4</td></tr><tr><td>250.6999969482422</td><td>5</td><td>2.506999969482422</td><td>5014</td><td>2018-07-21 13:53:32.530695</td><td>24</td></tr><tr><td>126.80000305175781</td><td>13</td><td>1.2680000066757202</td><td>2536</td><td>2018-07-22 14:24:34.530772</td><td>24</td></tr></tbody></table></div>

# %% [markdown]
# Create table statements from legacy systems exist in .txt files. Use sc.textFile to extract those original schemas for consumption

# %%
import re
###USE THIS CODE IF YOU ARE LOADING IN A .TXT FILE FOR THE CREATE TABLE STATEMENT
sample_sql = sc.textFile(name=f"{file_path}/{table_name}.txt", use_unicode=True).collect()[0] 
regex_matcher_schema = re.findall(r"\(([^)]+)", sample_sql)
schema_for_create_table = regex_matcher_schema[0] + ',' + regex_matcher_schema[1]
schema_for_query = ', '.join(i for i in re.findall(r"`(.*?)`", schema_for_create_table))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(schema_for_create_table)
print(schema_for_query)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">`calories_burnt` double, `device_id` bigint, `miles_walked` double, `num_steps` bigint, `time_stamp` timestamp, `sample_new_field` string,`user_id` bigint
# calories_burnt, device_id, miles_walked, num_steps, time_stamp, sample_new_field, user_id
# </div>

# %% [markdown]
# Create Delta Table with consumption schema

# %%
spark.sql(f"""CREATE TABLE IF NOT EXISTS Parse_{table_name} ({schema_for_create_table}) \
USING DELTA \
LOCATION '{file_path}/Parse/{table_name}' \
PARTITIONED BY (user_id)""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: DataFrame[]</div>

# %%
# %sql
show tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>default</td><td>parse_calories_burnt</td><td>false</td></tr></tbody></table></div>

# %% [markdown]
# Convert timestamp from string to TimestampType and use mergeSchema option to infer the schema from the consumption layer

# %%
from pyspark.sql.types import TimestampType

df = spark.readStream.format('delta') \
.load(f'{file_path}/Ingest/{table_name}') \
.withColumn('time_stamp', col('time_stamp').cast(TimestampType())) \
.writeStream \
.trigger(once=True) \
.format("delta") \
.option("checkpointLocation", f"{file_path}/Checkpoints/Parse/{table_name}") \
.option("mergeSchema", "true") \
.outputMode("append") \
.queryName("example_parse_stream") \
.partitionBy("user_id") \
.start(f'{file_path}/Parse/{table_name}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Check differences between Ingest and Parse schemas (time_stamp + added column "sample_new_field")

# %%
spark.read.load(f'{file_path}/Ingest/{table_name}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: DataFrame[calories_burnt: double, device_id: bigint, miles_walked: double, num_steps: bigint, time_stamp: string, user_id: bigint]</div>

# %%
spark.read.load(f'{file_path}/Parse/{table_name}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: DataFrame[calories_burnt: double, device_id: bigint, miles_walked: double, num_steps: bigint, time_stamp: timestamp, sample_new_field: string, user_id: bigint]</div>

# %%
spark.sql(f"""CREATE TABLE IF NOT EXISTS DeDuplicate_{table_name} ({schema_for_create_table}) \
USING DELTA \
LOCATION '{file_path}/DeDuplicate/{table_name}' \
PARTITIONED BY (user_id)""")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[27]: DataFrame[]</div>

# %% [markdown]
# "MERGE INTO" statement that both removes duplicates in my inserted file + prevents duplicates from loading in

# %%
def upsertToDelta(microBatchOutputDF, batchId):
  # set the dataframe to view name
  
  microBatchOutputDF.createOrReplaceTempView("updates")
  
  microBatchOutputDF._jdf.sparkSession().sql(f"""
  MERGE INTO delta.`{file_path}/DeDuplicate/{table_name}` as new
  USING (select {schema_for_query} from
  (select *,
  Row_number() OVER (PARTITION BY user_id, device_id
  ORDER BY user_id,device_id desc) num
  from updates) where num = 1) old
  ON old.user_id = new.user_id and old.device_id  = new.device_id
  WHEN NOT MATCHED THEN INSERT *
  """)

#be sure not to use a filter when it is the initial load.
updates = spark.readStream.format("delta").load(f'{file_path}/Parse/{table_name}')

# Start the query to upsert
updates.writeStream \
  .format("delta") \
  .foreachBatch(upsertToDelta) \
  .trigger(once=True) \
  .outputMode("update") \
  .start() \
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[28]: &lt;pyspark.sql.streaming.StreamingQuery at 0x7f057d425320&gt;</div>

# %%
display(spark.sql(f"""SELECT * FROM DeDuplicate_{table_name}"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>calories_burnt</th><th>device_id</th><th>miles_walked</th><th>num_steps</th><th>time_stamp</th><th>sample_new_field</th><th>user_id</th></tr></thead><tbody><tr><td>365.70001220703125</td><td>5</td><td>3.6570000648498535</td><td>7314</td><td>2018-07-24T02:37:36.530+0000</td><td>null</td><td>4</td></tr><tr><td>250.6999969482422</td><td>5</td><td>2.506999969482422</td><td>5014</td><td>2018-07-21T13:53:32.530+0000</td><td>null</td><td>24</td></tr><tr><td>126.80000305175781</td><td>13</td><td>1.2680000066757202</td><td>2536</td><td>2018-07-22T14:24:34.530+0000</td><td>null</td><td>24</td></tr></tbody></table></div>
